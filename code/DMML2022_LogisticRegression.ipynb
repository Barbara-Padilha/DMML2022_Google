# %% [markdown]
# # Data Mining and Machine Learning - Project
#
# ## Detecting Difficulty Level of French Texts Using Logistic Regression Classification.

# %% [markdown]
# Import the main packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")

# %% [markdown]
# Read the training data

# %%
df = pd.read_csv('training_data.csv')
df.head()
# Out:
#    id                                           sentence difficulty
# 0   0  Les coûts kilométriques réels peuvent diverger...         C1
# 1   1  Le bleu, c'est ma couleur préférée mais je n'a...         A1
# 2   2  Le test de niveau en français est sur le site ...         A1
# 3   3           Est-ce que ton mari est aussi de Boston?         A1
# 4   4  Dans les écoles de commerce, dans les couloirs...         B1

# %% [markdown]
# Read the unlabelled test data, on which to make predictions

# %%
df_pred = pd.read_csv('unlabelled_test_data.csv')
df_pred.head()
# Out:
#    id                                           sentence
# 0   0  Nous dûmes nous excuser des propos que nous eû...
# 1   1  Vous ne pouvez pas savoir le plaisir que j'ai ...
# 2   2  Et, paradoxalement, boire froid n'est pas la b...
# 3   3  Ce n'est pas étonnant, car c'est une saison my...
# 4   4  Le corps de Golo lui-même, d'une essence aussi...

# %% [markdown]
# The submission format is the following:

# %%
df_example_submission = pd.read_csv('sample_submission.csv')
df_example_submission.head()
# Out:
#    id difficulty
# 0   0         A1
# 1   1         A1
# 2   2         A1
# 3   3         A1
# 4   4         A1

# %% [markdown]
# ### Check the value of the baseline
#
# Check the baseline to have a better understanding of the precision of the classification

# %%
np.random.seed = 0

# %%
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier

# %%
# Define x and y, and the respective training data and test data
x = df['sentence']
y = df['difficulty']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
# Baseline - using dummy classifier
dummy = DummyClassifier(strategy='most_frequent')

dummy.fit(None, y_train)
baseline = dummy.score(None, y_test)

print('The value of the baseline in our data is',baseline.round(4))
# Out:
# The value of the baseline in our data is 0.1677

# %%
# Baseline - identifying the most frequent difficulty
df.difficulty.value_counts()
# Out:
# A1    813
# C2    807
# C1    798
# B1    795
# A2    795
# B2    792
# Name: difficulty, dtype: int64

# %%
baseline2 = round(df.difficulty.value_counts()['A1']/len(df),4)

print('The value of the baseline in our data is',baseline2.round(5))
# Out:
# The value of the baseline in our data is 0.1694

# %% [markdown]
# #### Logistic Regression (without data cleaning)
#
# Train a simple logistic regression model using a Tfidf vectoriser.

# %% [markdown]
# In order to classify text, we need to use a vectorizer and also import certain packages. It is also important to note that while installing the packages, you must import the correct language you will be classifying.

# %%
# Install and update spaCy
# !pip install -U spacy
# !python -m spacy download fr

# Import necessary packages
import spacy
from spacy import displacy
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.pipeline import Pipeline
import string
from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop
from spacy.lang.fr import French
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.3)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2022-12-08 21:35:22.377084: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ⚠ As of spaCy v3.0, shortcuts like 'fr' are deprecated. Please use the
# full pipeline package name 'fr_core_news_sm' instead.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fr-core-news-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.4.0/fr_core_news_sm-3.4.0-py3-none-any.whl (16.3 MB)
#      |████████████████████████████████| 16.3 MB 5.1 MB/s
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from fr-core-news-sm==3.4.0) (3.4.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (1.10.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (1.0.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (3.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (3.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (57.4.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (0.7.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (1.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (4.64.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (2.11.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (8.1.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (2.4.5)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (0.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (21.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (1.21.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (1.24.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->fr-core-news-sm==3.4.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %% [markdown]
# Define the vectorizer and the classification method that will be used, once those are defined, create a pipeline to classify the training set.

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2))
lr = LogisticRegression(solver='lbfgs', max_iter=10000, random_state=0)

pipe = Pipeline([('vectorizer', tfidf),
                 ('classifier', lr)])

pipe.fit(x_train, y_train)

y_pred = pipe.predict(x_test)
y_pred
# Out:
# array(['C2', 'A2', 'B1', 'B2', 'A1', 'A1', 'B1', 'B2', 'B1', 'A2', 'B2',
#        'A2', 'C2', 'B1', 'A2', 'B2', 'C1', 'C1', 'A1', 'A1', 'A2', 'B1',
#        'A1', 'C1', 'B2', 'C2', 'C2', 'B2', 'B2', 'C2', 'B1', 'A2', 'A2',
#        'A1', 'A1', 'B1', 'C2', 'A2', 'B2', 'A1', 'B2', 'A1', 'B2', 'B2',
#        'C1', 'C1', 'B1', 'C1', 'B2', 'C1', 'B1', 'A1', 'B2', 'A1', 'B2',
#        'C1', 'C1', 'B2', 'B1', 'B2', 'B1', 'C1', 'A2', 'B1', 'C2', 'B1',
#        'A2', 'B1', 'A1', 'A1', 'C2', 'A2', 'C2', 'C2', 'A1', 'A2', 'B1',
#        'C2', 'B2', 'C1', 'C2', 'A2', 'C1', 'B2', 'C2', 'C1', 'A2', 'B2',
#        'A1', 'A1', 'C2', 'C1', 'C2', 'C2', 'B2', 'B1', 'B2', 'B2', 'A1',
#        'C1', 'A1', 'A1', 'C1', 'A1', 'A1', 'A1', 'A1', 'A2', 'C2', 'A2',
#        'B1', 'B2', 'A2', 'A1', 'A2', 'A1', 'A2', 'B2', 'C1', 'A2', 'B2',
#        'B1', 'A1', 'C1', 'A2', 'C2', 'B1', 'A1', 'A1', 'A2', 'C1', 'C1',
#        'A1', 'A1', 'A1', 'A1', 'A2', 'A1', 'A1', 'B2', 'C1', 'B2', 'C1',
#        'B2', 'C1', 'B2', 'B1', 'B1', 'A2', 'C1', 'B1', 'C2', 'B1', 'A2',
#        'C2', 'C2', 'A2', 'C2', 'A2', 'C1', 'B2', 'C1', 'A2', 'A2', 'A2',
#        'C2', 'A1', 'A1', 'C2', 'A2', 'C1', 'B2', 'C1', 'C2', 'C2', 'B2',
#        'B1', 'A2', 'B1', 'A1', 'B2', 'B1', 'A2', 'C2', 'A1', 'B2', 'C1',
#        'C2', 'C2', 'B2', 'A1', 'C1', 'B2', 'A1', 'B1', 'C1', 'C2', 'C2',
#        'B2', 'B2', 'C1', 'A2', 'C1', 'A1', 'C1', 'B2', 'C1', 'A2', 'C2',
#        'C1', 'B1', 'B2', 'C2', 'B2', 'A2', 'B1', 'C2', 'C2', 'A2', 'A1',
#        'C2', 'B1', 'A1', 'A2', 'C2', 'C1', 'C2', 'C2', 'C1', 'B2', 'A1',
#        'C2', 'C2', 'C2', 'C1', 'A1', 'B2', 'B2', 'B1', 'C2', 'A1', 'A1',
#        'A1', 'B2', 'C2', 'B1', 'B1', 'A2', 'C1', 'C2', 'B1', 'B2', 'C2',
#        'C2', 'A1', 'A2', 'C2', 'B1', 'B1', 'C2', 'A2', 'A2', 'C2', 'C2',
#        'C2', 'B2', 'B2', 'A1', 'B2', 'A2', 'A1', 'C1', 'A2', 'C1', 'C1',
#        'B2', 'C1', 'C2', 'A2', 'A2', 'A2', 'A1', 'A1', 'A1', 'C1', 'B1',
#        'A2', 'C1', 'A1', 'A1', 'A2', 'A2', 'A2', 'A1', 'B2', 'B1', 'C2',
#        'B2', 'A1', 'A1', 'C2', 'B1', 'C1', 'C1', 'B1', 'A1', 'C2', 'B1',
#        'A1', 'B2', 'B1', 'A1', 'A2', 'C1', 'C2', 'C2', 'C2', 'A2', 'C1',
#        'C1', 'C2', 'B1', 'A1', 'A1', 'A1', 'C2', 'B1', 'B2', 'B2', 'C1',
#        'C2', 'A2', 'C2', 'C1', 'B2', 'B1', 'B1', 'C2', 'C2', 'C2', 'A2',
#        'C2', 'A2', 'B1', 'C1', 'A1', 'C1', 'B1', 'C2', 'C2', 'A1', 'C2',
#        'B1', 'C1', 'C2', 'C1', 'C2', 'C2', 'A2', 'C2', 'C1', 'C2', 'B2',
#        'C1', 'A2', 'B1', 'C2', 'C2', 'A1', 'C2', 'B2', 'C1', 'A2', 'B2',
#        'B1', 'A1', 'C1', 'B2', 'C2', 'A1', 'A1', 'C2', 'A2', 'B2', 'A2',
#        'B2', 'C2', 'B1', 'B1', 'C2', 'B2', 'A2', 'A1', 'A2', 'A1', 'C2',
#        'A1', 'A2', 'A2', 'C1', 'B1', 'C1', 'A1', 'A2', 'A1', 'C2', 'C1',
#        'B1', 'B2', 'B2', 'A1', 'A2', 'B2', 'B2', 'B2', 'B1', 'B2', 'B1',
#        'C2', 'C2', 'B2', 'C2', 'A2', 'B1', 'A1', 'B2', 'A1', 'C1', 'A1',
#        'A1', 'C2', 'A2', 'C2', 'B1', 'B2', 'C1', 'A2', 'C2', 'C2', 'C1',
#        'C1', 'B1', 'A1', 'B1', 'B1', 'A1', 'A2', 'A2', 'B2', 'B2', 'C2',
#        'A1', 'C1', 'B1', 'C1', 'B1', 'C2', 'C1', 'A2', 'B2', 'B2', 'B1',
#        'A2', 'A2', 'B1', 'C1', 'A2', 'B2', 'C1', 'C2', 'C2', 'C1', 'B1',
#        'C2', 'A1', 'C1', 'B1', 'B1', 'C1', 'B1', 'C2', 'C1', 'A1', 'A2',
#        'A1', 'C1', 'B1', 'A1', 'C2', 'A1', 'A2', 'A1', 'A2', 'B2', 'B1',
#        'B2', 'B2', 'A2', 'C1', 'C1', 'C2', 'C2', 'B1', 'A2', 'C2', 'C1',
#        'C2', 'A1', 'C1', 'C2', 'C2', 'B2', 'A2', 'B1', 'A1', 'C2', 'A1',
#        'A2', 'A2', 'C2', 'C2', 'C1', 'B2', 'A1', 'C2', 'B2', 'C1', 'A2',
#        'C1', 'B1', 'A1', 'C1', 'C1', 'B1', 'C1', 'B1', 'A2', 'C2', 'C1',
#        'B1', 'C2', 'A1', 'B2', 'B2', 'C2', 'A1', 'A2', 'A2', 'A1', 'C2',
#        'A2', 'C1', 'A1', 'B1', 'B2', 'B2', 'C1', 'C2', 'B1', 'A1', 'B2',
#        'C2', 'C2', 'B2', 'C1', 'C2', 'A1', 'B2', 'C1', 'C1', 'C2', 'C1',
#        'A1', 'C2', 'A1', 'A2', 'B2', 'B2', 'A1', 'B1', 'B1', 'A2', 'C1',
#        'C2', 'A1', 'A2', 'A1', 'B2', 'A2', 'C2', 'B1', 'B1', 'C2', 'C2',
#        'B2', 'B1', 'C2', 'B1', 'B2', 'C2', 'A1', 'B1', 'A2', 'C2', 'C1',
#        'B1', 'B2', 'C2', 'A1', 'C2', 'A2', 'C2', 'A2', 'A2', 'B2', 'B2',
#        'B1', 'A2', 'C1', 'A1', 'A2', 'A2', 'A1', 'C2', 'B1', 'B1', 'C2',
#        'B2', 'A2', 'C1', 'A2', 'B2', 'C1', 'C2', 'C1', 'B2', 'A1', 'A2',
#        'C2', 'B2', 'A1', 'B2', 'B2', 'A2', 'A2', 'B2', 'B1', 'B2', 'C2',
#        'B2', 'A2', 'C1', 'C2', 'C1', 'A1', 'A1', 'A1', 'C2', 'B2', 'A2',
#        'B1', 'B2', 'B1', 'A1', 'C1', 'B2', 'A1', 'C1', 'B1', 'A1', 'A1',
#        'A1', 'A1', 'B2', 'C1', 'A1', 'A2', 'A2', 'B2', 'A2', 'C2', 'C1',
#        'B2', 'A2', 'B2', 'C1', 'A1', 'B2', 'C2', 'C2', 'A2', 'B1', 'C2',
#        'C2', 'A1', 'C2', 'A1', 'A1', 'C1', 'A2', 'A1', 'B1', 'A2', 'A1',
#        'B2', 'C1', 'B1', 'C1', 'A1', 'B1', 'B1', 'A2', 'B1', 'B1', 'C1',
#        'A2', 'B1', 'A1', 'A1', 'A1', 'C1', 'A1', 'A2', 'B2', 'C2', 'C2',
#        'C1', 'A1', 'A2', 'B2', 'A1', 'C1', 'C2', 'A1', 'A1', 'C1', 'B2',
#        'C2', 'C2', 'A1', 'B1', 'A2', 'B2', 'C1', 'A1', 'A2', 'C2', 'C1',
#        'B2', 'A2', 'A2', 'A2', 'B2', 'C2', 'B1', 'C2', 'A2', 'C1', 'A1',
#        'C1', 'C1', 'A1', 'B2', 'A2', 'B2', 'C2', 'A1', 'A2', 'B2', 'C1',
#        'C2', 'B1', 'A2', 'A2', 'B1', 'B2', 'A1', 'B1', 'B1', 'A1', 'C2',
#        'B2', 'B1', 'C2', 'B1', 'B1', 'B2', 'B1', 'A2', 'C1', 'C1', 'B2',
#        'A2', 'B1', 'A1', 'B2', 'A1', 'B1', 'C2', 'A2', 'B2', 'B1', 'A1',
#        'B2', 'A1', 'A2', 'C1', 'C2', 'B1', 'C2', 'A2', 'A1', 'A1', 'C1',
#        'A2', 'C1', 'C1', 'C2', 'B1', 'B2', 'C2', 'B1', 'B1', 'C2', 'C1',
#        'A1', 'B2', 'C2', 'B1', 'B1', 'C1', 'C1', 'A1', 'B2', 'B1', 'A1',
#        'B2', 'A2', 'A1', 'A1', 'B2', 'C2', 'B2', 'A2', 'A1', 'C1', 'C1',
#        'C2', 'C1', 'C1', 'C2', 'A1', 'B2', 'B1', 'C1', 'A2', 'C2', 'C2',
#        'A2', 'C1', 'C2', 'C1', 'C1', 'A1', 'A1', 'B2', 'C1', 'C1', 'B1',
#        'C2', 'B2', 'B1', 'B1', 'A1', 'C1', 'C2', 'C2', 'A1', 'C2', 'A1',
#        'A2', 'B1', 'B1', 'B2', 'C1', 'A1', 'B1', 'A1', 'C2', 'B1', 'A1',
#        'B1', 'B2', 'A2', 'B1', 'C2', 'A1', 'C1', 'C1', 'B1', 'B1', 'B1',
#        'C1', 'B1', 'A1', 'C1', 'C1', 'A2', 'B2', 'B2', 'C1', 'B1', 'B2',
#        'C2', 'A2', 'B2', 'C1', 'A1', 'A1', 'B1', 'C1', 'B1', 'C1', 'C1',
#        'A2', 'A1', 'B2', 'C1', 'B1', 'A2', 'A2', 'A1', 'C2', 'B1', 'B1',
#        'C2', 'A2', 'A1', 'A1', 'A2', 'C1', 'A2', 'B1', 'C2', 'B2', 'A2',
#        'A2', 'A1', 'B2', 'C2', 'B2', 'C2', 'B2', 'B1', 'A2', 'B2', 'B2',
#        'B2', 'B1', 'B2'], dtype=object)

# %% [markdown]
# In order to analyse our results, we calculated the accuracy, precision, recall and F1 score on the test set, besides plotting the confusion matrix.

# %%
def evaluate(true, pred):
    global precision,recall,f1
    precision = precision_score(true, pred, average='weighted')
    recall = recall_score(true, pred, average='weighted')
    f1 = f1_score(true, pred, average='weighted')
    print(f"CONFUSION MATRIX:\n{confusion_matrix(true, pred)}")
    print(f"ACCURACY SCORE:\n{accuracy_score(true, pred):.4f}")
    print(f"CLASSIFICATION REPORT:\n\tPrecision: {precision:.4f}\n\tRecall: {recall:.4f}\n\tF1_Score: {f1:.4f}")

# %%
evaluate(y_test,y_pred)
# Out:
# CONFUSION MATRIX:
# [[89 41 22  6  2  1]
#  [50 59 32 10  9  4]
#  [14 37 63 18 11 17]
#  [10  2 14 59 34 25]
#  [ 4  4 10 38 67 50]
#  [ 7  8  5 25 32 81]]
# ACCURACY SCORE:
# 0.4354
# CLASSIFICATION REPORT:
# 	Precision: 0.4340
# 	Recall: 0.4354
# 	F1_Score: 0.4337

# %% [markdown]
# We can now have a look at sentences that are not well classified. In order to do that we need to compare the results obtained by the classification with the values already given for the test set.

# %%
y_pred_df = pd.DataFrame(data=y_pred)
y_pred_df.columns = ['difficulty']
y_test_df = pd.DataFrame(data=y_test).reset_index().drop(['index'],axis=1)
x_test_df = pd.DataFrame(data=x_test).reset_index().drop(['index'],axis=1)

# %%
df_check = (y_pred_df != y_test_df)

# %%
for i in range(len(df_check)):
  if df_check['difficulty'][i]==True:
    print('Example of a wrongly classified text:',x_test_df['sentence'][i])
  else:
    print('Text correctly classified')
# Out:
# Example of a wrongly classified text: C'est en décembre 1967, après bien des invectives au Parlement, que sa loi relative à la régulation des naissances, dite loi Neuwirth est votée : elle autorise la vente exclusive des contraceptifs en pharmacie sur ordonnance médicale, avec autorisation parentale pour les mineures
# Example of a wrongly classified text: Giscard va pourtant réussir à transformer ce revers en tremplin
# Example of a wrongly classified text: Un choix difficile mais important : le public français écoute souvent les professionnels de Cannes pour choisir le film qu'il va aller voir au cinéma.
# Example of a wrongly classified text: Le débat porte plutôt sur l'utilité d'une telle mesure.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Il faut du temps et du courage pour soigner toute cette ménagerie En plus des animaux, il faut aussi s'occuper du potager de mon papy
# Example of a wrongly classified text: Vous eussiez juré que les gens la voyaient, l'entendaient rouler pesamment devant eux, retentissante de tous les trésors enfermés dans ses flancs.
# Text correctly classified
# Example of a wrongly classified text: Mon frère Patrice est plus jeune que moi, il va à l'école des petits.
# Example of a wrongly classified text: Le risque de plagiat?
# Example of a wrongly classified text: Je vous souhaite bonne année pleine de bonheur et de joie Bbonne continuation Merci Bachy pour ton message !
# Example of a wrongly classified text: Le visage comprend une oreille de chaque côté, deux yeux surmontés par les sourcils et un nez au centre
# Example of a wrongly classified text: Le revenu des enfants sous autorité parentale est ajouté à celui du détenteur de l'autorité parentale.
# Example of a wrongly classified text: Que voulez-vous ?
# Text correctly classified
# Example of a wrongly classified text: Avec la distanciation sociale, les occasions de se réunir ont également été moins fréquentes.
# Example of a wrongly classified text: Après avoir identifié les inconvénients de la robotisation, j'exposerai ses avantages.
# Example of a wrongly classified text: Je ne sais pas ; pas beaucoup peut-être ; pas assez en tout cas.
# Text correctly classified
# Example of a wrongly classified text: Je m'occupe de mes deux enfants quand ils rentrent de l'école.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Oui, des feux de forêt qui frappent le sud-est du pays depuis le mois de septembre et qui ont fait une 24e victime ce week-end
# Example of a wrongly classified text: Seuls les membres de la société de personnes ont la qualité de contribuables, ainsi le revenu et la fortune nets de la société sont attribués proportionnellement aux personnes physiques formant la société.
# Example of a wrongly classified text: La nuit vient de tomber sur Calcutta et la tempête entre en ville avec une puissance terrifiante
# Example of a wrongly classified text: Les masses liquides transportent les plus grandes espèces connues de mammifères, et peut-être recèlent-elles des mollusques d'une incomparable taille, des crustacés effrayants à contempler, tels que seraient des homards de cent mètres ou des crabes pesant deux cents tonnes !
# Text correctly classified
# Example of a wrongly classified text: Les articulations sont en haut la hanche, au milieu le genou en en bas la cheville
# Example of a wrongly classified text: Toutes ces données indiquent "que le problème de la malnutrition devient plus complexe et que les stratégies de lutte des pays et des organisations internationales devront s'attaquer au triple fardeau qui pèse désormais sur les pays en développement : les maladies infectieuses, les carences alimentaires et les maladies chroniques liées à la surcharge pondérale", précise Francis Delpeuch.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Il trouve bizarre que l'artiste ait quitté le concert avant la fin samedi soir dernier.
# Example of a wrongly classified text: Il t'ordonne de partir immédiatement !
# Example of a wrongly classified text: Elle s'est ensuite élargie à d'autres établissements
# Example of a wrongly classified text: C'est une charmante ville.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Il y a aussi les personnages dotés d'un pouvoir politique séculier exceptionnel : les rois.
# Text correctly classified
# Example of a wrongly classified text: Eviter d'importer de l'inflation et surtout contrôler le niveau de change du franc suisse par rapport aux grandes devises internationales et notamment face à l'euro et au dollar.
# Example of a wrongly classified text: [Les dames rient] Je pense qu'il y aurait de la bagarre, hein
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Voici un extrait de sa conférence à Lannion, le 28 mai 1988
# Example of a wrongly classified text: Forts des expériences, parfois malheureuses, de leurs aînés, certains jeunes anticipent.
# Text correctly classified
# Example of a wrongly classified text: Attention, vous devez certifier conformes la version papier des statuts de votre entreprise et celle de votre pièce d'identité, puis vous devez les signer de façon manuscrite avant de les scanner.
# Text correctly classified
# Example of a wrongly classified text: C'est la couleur de nombreux fruits et légumes, comme les tomates, les fraises ou les cerises.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Pourtant, on a environ 200 entreprises qui sont prêtes à embaucher par vingtaine, trentaine tous les ans et qui ont du mal à recruter des développeurs de qualité.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: On peut montrer le nouveau père en exemple à destination d'autres pères moins impliqués, mais sans en faire ni un objet de curiosité ni un héros absolu auquel il faudrait dresser une statue.
# Example of a wrongly classified text: Mais trop de gens sont encore désarmés face aux ordinateurs.
# Example of a wrongly classified text: As-tu besoin de quelque chose?
# Example of a wrongly classified text: Ce texte milite pour corriger un préjugé sur les aptitudes intellectuelles des femmes.
# Text correctly classified
# Example of a wrongly classified text: J'ai hâte que tu viennes me rendre visite le mois prochain, pour te montrer mes endroits préférés
# Example of a wrongly classified text: Les trompettes, les fifres, les hautbois, les tambours, les canons, formaient une harmonie telle qu'il n'y en eut jamais en enfer.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Dans une clairière enneigée, entourée d'arbres dénudés, une Citroën AX blance, bien fatiguée, attelée d'une remorque de type frigorifique, aurait l'air abandonnée si l'on ne distinguait quatre hommes aux cheveux très longs, assis dans la voiture.
# Example of a wrongly classified text: L'après-midi, j'ai encore beaucoup de choses à faire
# Example of a wrongly classified text: Chez nous, c'est nuageux.
# Example of a wrongly classified text: Le romancier qui transforme la vérité constante, brutale et déplaisante, pour en tirer une aventure exceptionnelle et séduisante, doit, sans souci exagéré de la vraisemblance, manipuler les événements à son gré; les préparer et les arranger pour plaire au lecteur, l'émouvoir ou l'attendrir.
# Example of a wrongly classified text: Il pleut et j'attends l'autobus
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Quelle tête à claques celle-là !
# Example of a wrongly classified text: J'ai déjà pris l'avion car nous sommes allés à Rome en Italie, il y a deux ans
# Example of a wrongly classified text: À Milan, dix fois par jour il voyait le prince Eugène, et eût pu lui adresser la parole.
# Text correctly classified
# Example of a wrongly classified text: Certains, pourtant, haïssent cette béance dans leur agenda, ce vide, ce temps mort.
# Text correctly classified
# Example of a wrongly classified text: En attribuant une valeur de flux potentiel aux liens du graphe, la segmentation fondée sur le critère de modularité aboutit à un découpage considéré comme optimal du point de vue de la dynamique démographique interne à chaque compartiment.
# Example of a wrongly classified text: Folio n'arrive pas à s'endormir.
# Example of a wrongly classified text: Alors qu'au cours du Paléolithique, la diffusion avait fractionné l'écoumène en petits groupes, la tendance depuis la fin de la dernière glaciation est à l'épaississement des relations dans l'Ancien Monde, par augmentation des effectifs et par tissage d'interconnexions.
# Example of a wrongly classified text: Le Canada se trouve au nord de l'amerique
# Example of a wrongly classified text: C'était là le fruit qu'il avait retiré des études astrologiques de son ami l'abbé Blanès, aux prédictions duquel il ne croyait point.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Cinq ans plus tard, VGE mène une campagne présidentielle moderne, inspirée de celle de Kennedy aux États-Unis
# Text correctly classified
# Example of a wrongly classified text: Aujourd'hui, je vais te présenter ma famille.
# Text correctly classified
# Example of a wrongly classified text: Ils ont tout planifié six mois à l'avance, afin de bénéficier des tarifs les plus avantageux, ce qui leur a permis par exemple de réserver un hôtel quatre étoiles au lieu de trois
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Après qu'il eut révélé son terrible secret, il se sentit soulagé
# Example of a wrongly classified text: Toutes ces fêtes ont le même but : remercier les mamans pour ce qu'elles font toute l'année !
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: La violence des vols et des agressions scande l'itinérance d'un vagabond qui fréquente le monde des individus statiques, auquel l'auteur ne se rattache plus, et celui des bas-fonds, qui l'inquiète ou le dégoûte.
# Example of a wrongly classified text: C'est une bonne nouvelle, mais comment je vais faire dans une si grande ville alors que j'adore la nature?
# Example of a wrongly classified text: Tu as entendu ce bruit ?
# Text correctly classified
# Example of a wrongly classified text: En allant à la campagne, nous aurions cueilli des petits fruits.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Il arrive bientôt.
# Text correctly classified
# Example of a wrongly classified text: Mais au fait, qu'est-ce que c'est le tourisme responsable ?
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Quand Ulysse fut parti, Pénélope demeura pensive.
# Text correctly classified
# Example of a wrongly classified text: Pour y aller, descendez à la station musée du Louvre, prenez à droite et continuez tout droit
# Example of a wrongly classified text: Je ne vais pas aller avec eux, puisqu'ils sont déjà partis !
# Text correctly classified
# Example of a wrongly classified text: Le lendemain, le 25 décembre, est le jour de Noël
# Example of a wrongly classified text: D'ailleurs, tous les personnages masculins croisés par l'héroïne - en dehors de ses collègues - sont dans un rapport de séduction.
# Example of a wrongly classified text: Le jour de l'An correspond au 1 janvier.
# Example of a wrongly classified text: Il est vrai que Pierre a moins de livres que ses amis, mais les siens sont meilleurs.
# Example of a wrongly classified text: Un phénomène d'autant plus inquiétant que ce n'est pas la première fois qu'il se produit
# Text correctly classified
# Example of a wrongly classified text: Sa santé s'est dégradée à cause d'une infection sévère et ses jours sont comptés.
# Example of a wrongly classified text: Quelqu'un a essayé de brûler la maison et on ignore qui et pourquoi.
# Example of a wrongly classified text: Mais on entendit trois coups sur la scène ; un roulement de timbales commença, les instruments de cuivre plaquèrent des accords, et le rideau, se levant, découvrit un paysage.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Tu descends l'escalier et tu tournes à gauche.
# Example of a wrongly classified text: Hier, en raison de violents orages, des villageois ont été privés d'électricité.
# Example of a wrongly classified text: D'après des témoignages de chefs d'entreprise recueillis dans le Guide France Info Le salarié handicapé dans l'entreprise, ce dernier est un salarié comme les autres, avec en plus, la volonté de s'en sortir .
# Example of a wrongly classified text: Il y a essentiellement trois grandes catégories.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Merci Gaio, Ne t'inquiète pas, fais à ton rythme.
# Text correctly classified
# Example of a wrongly classified text: Il est interdit de fumer
# Text correctly classified
# Example of a wrongly classified text: Leurs enfants sont grands (ceux du premier lit du moins), leurs emprunts remboursés, leurs revenus souvent confortables - ils détiennent 60% de la richesse nationale et 50% du revenu net des ménages français - ils sont propriétaires de leur logement dans 8 cas sur 10 et possèdent un autre bien immobilier dans 1 cas sur 3.
# Text correctly classified
# Example of a wrongly classified text: Craignant la défaite électorale, Trump dégobille allègrement sur le système électoral, parle de fraude et d'irrégularités, comme si elles étaient monnaie courante.
# Example of a wrongly classified text: Les robots humanoïdes n'en sont qu'à leurs balbutiements.
# Example of a wrongly classified text: Au cours de ces trente années, deux vies se déroulent donc devant nos yeux, avec leur lot de grands chagrins et d'amourettes, de déceptions et d'emballements.
# Example of a wrongly classified text: Notre papier comporte en premier lieu une description détaillée des données étudiées, ainsi que diverses analyses concernant ces dernières.
# Example of a wrongly classified text: Puis, plus grand, je découvrais les métiers de policier et d'avocat dans un film.
# Example of a wrongly classified text: Puis, ayant rêvé pour la troisième fois qu'il voyait l'Enchanteresse, dont aucunes paroles humaines, cette nuit-là, n'eussent pu dépeindre le charme et le rayonnement, il s'en fut en secret le lendemain, sans consulter personne, et s'alla perdre, tout seul, dans la forêt.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: L'idée était de stimuler chez les élèves l'esprit scientifique et les capacités d'expression, de favoriser leur compréhension du monde, et de leur permettre de mieux jouer leur rôle de citoyen en proposant des projets pédagogiques orientés vers des questions de société (éducation à la santé, au développement durable .) avec pour objectif que chacun de ces projets touche en moyenne 10'000 classes.
# Example of a wrongly classified text: Il y a beaucoup de pièces
# Example of a wrongly classified text: Tout comme la révolution industrielle a vu naître le capitalisme, je suis persuadé que la robolution va profondément modifier notre système économique.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Le principe général adopté pour identifier les zones de vulnérabilité repose sur la "méthode de la suppression" : partant d'une certaine métrique de connectivité calculée pour l'ensemble du graphe, elle consiste à simuler successivement la suppression de tous les éléments du graphe (taches ou liens) et à calculer pour chacun le taux de variation entre la valeur initiale de la métrique et la valeur tenant compte de la suppression.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Cela fait partie de sa vie sociale.
# Example of a wrongly classified text: Les quelques chiffres publiés à ce jour donnent une idée de la dégradation du climat entre les élèves des deux sexes.
# Example of a wrongly classified text: Soixante associations de défense de l'environnement et de solidarité sociale ont mis en garde contre une possible exclusion de l'obligation de rénovation énergétique des logements dans la future loi sur le climat.
# Example of a wrongly classified text: "Friendly" pour "Amicalement" est tout simplement un non-sens
# Example of a wrongly classified text: En conduisant un véhicule, vous ne pouvez pas téléphoner.
# Example of a wrongly classified text: Quand je reviendrai, j'offrirai beaucoup d'amour à ceux que j'aprécie et je couvrirai mes enfants de présents.
# Example of a wrongly classified text: Que les marquis se taisent sur leurs bancs, ou bien je fais tâter ma canne à leurs rubans !
# Example of a wrongly classified text: Je ne pourrai pas venir demain.
# Example of a wrongly classified text: Tu dois te couper les ongles.
# Example of a wrongly classified text: Plus grave, un lien a été mis en évidence entre ces usages et des symptômes de dépression.
# Example of a wrongly classified text: Je vais à l'école pendant la journée. Mon père s'appelle Alain.
# Example of a wrongly classified text: Cependant, les bougies de l'orchestre s'allumèrent; le lustre descendit du plafond, versant, avec le rayonnement de ses facettes, une gaieté subite dans la salle; puis les musiciens entrèrent les uns après les autres, et ce fut d'abord un long charivari de basses ronflant, de violons grinçant, de pistons trompétant, de flûtes et de flageolets qui piaulaient.
# Example of a wrongly classified text: Nous avons l'habitude d'acheter quinze pommes, ce sont elles qui les comptent et les mettent dans notre panier.
# Example of a wrongly classified text: D'autres auteurs ont exploité ce terrain comme Erik Orsenna et ses Chevaliers du subjonctif, sorti à l'automne 2004 (Le Monde de l'éducation n° 328, septembre 2004)
# Example of a wrongly classified text: Si l'individualisme repose sur le culte de chacun pour soi, l'individualisation correspond à une culture du choix, chacun affirmant son autonomie, sa capacité d'orienter son action sans être contrôlé ou contraint.
# Example of a wrongly classified text: Elle prendra un pseudonyme masculin pour poursuivre ses travaux qui, revisités il y a peu, ont montré qu'elle avait imaginé les prémisses des travaux de Poincaré.
# Example of a wrongly classified text: La première modernité a inventé l'universalisme abstrait, qui définissait tout ce que les individus ont en commun.
# Example of a wrongly classified text: Quand il arriva près de la maison il vit un monsieur à la porte, et il entendit qu'il disait à la femme : "Ma bonne femme, votre mari est-il chez lui ?" "Non monsieur," répondit la femme.
# Text correctly classified
# Example of a wrongly classified text: Il goûta cette sauce aussitôt que tu la eus préparée.
# Example of a wrongly classified text: Je me demande si les fourmis dorment.
# Example of a wrongly classified text: La Fête des mères est un jour très spécial durant lequel les mamans sont mises à l'honneur.
# Example of a wrongly classified text: Quand les clients viennent, on a l'impression qu'ils viennent dans un endroit féerique
# Text correctly classified
# Example of a wrongly classified text: C'est aussi un test pour les couples nouvellement formés ou qui n'avaient jamais expérimenté la vie à deux.
# Text correctly classified
# Example of a wrongly classified text: Les occasions d'opposition, dues aux différences de culture, sont plus nombreuses.
# Example of a wrongly classified text: Le 1er mai correspond à la fête du Travail, et rappelle la lutte des ouvriers pour réduire la journée de travail à huit heures.
# Example of a wrongly classified text: Giscard se laisse filmer durant ses vacances à la montagne ou à la plage, il apparaît en short, puis torse nu lors d'un match de football organisé entre notables de Chamalières, village dont il fut longtemps le maire
# Text correctly classified
# Example of a wrongly classified text: Ainsi l'abbé Blanès n'avait pas communiqué sa science assez difficile à Fabrice ; mais, à son insu, il lui avait inoculé une confiance illimitée dans les signes qui peuvent prédire l'avenir.
# Text correctly classified
# Example of a wrongly classified text: En Suisse les personnes physiques peuvent être assujetties à l'impôt sur le revenu et la fortune en raison de leurs liens personnels ou leur rattachement économique avec la Suisse.
# Text correctly classified
# Example of a wrongly classified text: Tu mangeas les petits fruits dès que tu les eus cueillis
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Devenus protocole et politesses rituelles, les mots d'amour glissaient sur la toile cirée de l'habitude.
# Example of a wrongly classified text: Le lendemain, en se promenant, il rencontra un gueux tout couvert de pustules, les yeux morts, le bout du nez rongé, la bouche de travers, les dents noires, et parlant de la gorge, tourmenté d'une toux violente et crachant une dent à chaque effort.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Les dents se trouvent dans la bouche
# Example of a wrongly classified text: Ils se sont dits des mots d'amour, des mots de tous les jours!
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Mes peines : une peine est un chagrin, une douleur, un malheur.
# Example of a wrongly classified text: Cet emballage innovant, allié au développement des lignes de chemin de fer, permit la distribution du camembert dans d'autres régions de France, mais aussi à l'étranger.
# Example of a wrongly classified text: Pour nous reposer, nous avons bu un verre en terrasse
# Example of a wrongly classified text: Robert percevait même les grincements du grillage contre lequel il devait se lancer de toutes ses forces.
# Example of a wrongly classified text: Quand il y a des nuages avec de la neige qui tombe, c'est qu'il va neiger et qu'il peut y avoir du brouillard, des risques de congélation, de la glace et que la température sera très basse
# Text correctly classified
# Example of a wrongly classified text: Le parc national de Chamonix a besoin de 5 guides pour l'été.
# Example of a wrongly classified text: Je n'ai aucune nouvelle depuis son départ
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Elle ne travaille plus ici depuis quinze jours.
# Example of a wrongly classified text: La tête se compose du visage et du crâne qui est recouvert de cheveux
# Example of a wrongly classified text: Il y a cinq chambres, une grande cuisine, un salon et deux salles de bains
# Example of a wrongly classified text: Loin de faire l'unanimité, le téléphone mobile est souvent comparé à un cordon ombilical qui entrave l'autonomie, maintient la dépendance, infantilise.
# Example of a wrongly classified text: Tu vois le château là-bas ?
# Text correctly classified
# Example of a wrongly classified text: Le plus inquiétant c'est que la Scandinavie avait déjà battu des records de chaleur pendant l'été 2018
# Example of a wrongly classified text: Quand j'échange avec des sympathisants de gauche en mettant sur la table toutes les réformes de progrès social depuis 2017, je me rends compte que l'enjeu porte avant tout sur notre capacité à porter politiquement ce bilan.
# Example of a wrongly classified text: Réaffirmant que le Sénat ne s'était livré à aucun chantage contrairement aux allégations du rapporteur pour l'Assemblée nationale, il a, au contraire, affirmé que la position de la Haute Assemblée relevait d'une conception cohérente et constante de la société.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Il accepte les différences, il est tolérant.
# Text correctly classified
# Example of a wrongly classified text: Lucie s'avançait, à demi soutenue par ses femmes, une couronne d'oranger dans les cheveux, et plus pâle que le satin blanc de sa robe.
# Text correctly classified
# Example of a wrongly classified text: Les nouvelles technologies ont subi une évolution très rapide depuis les années 1970 et ont entraîné une véritable révolution dans nos habitudes et notre mode de pensée.
# Example of a wrongly classified text: Je suis persuadé que la robolution va profondément modifier notre système économique.
# Text correctly classified
# Example of a wrongly classified text: C'est dramatique qu'ils aient été amnésique suite au terrible accident survenu lors des tests de laboratoire.
# Example of a wrongly classified text: Le héros est mort à la fin du film.
# Example of a wrongly classified text: Née de la contraction anglaise de "no-mobile phobia", la nomophobie est, en simplifiant, une crainte obsédante et continuelle, de ne pas avoir son smartphone en état de marche avec soi.
# Example of a wrongly classified text: Je fais mon lit tous les jours, bien sûr; et je fais souvent la vaisselle.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Cette première étape est celle de l'apprentissage de l'autre, celle où chacun souhaite vaincre ses craintes et relever le défi.
# Text correctly classified
# Example of a wrongly classified text: C'est pour quand ?
# Example of a wrongly classified text: On aura beaucoup de travail jusqu'au mois de mai.
# Text correctly classified
# Example of a wrongly classified text: Son espace virtuel, unique en son genre, fête ses deux ans d'existence, et propose une belle collection d'alternatives au cahier de vacances
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Essayez maintenant d'identifier les mots de vocabulaire dans l'histoire en l'écoutant à nouveau.
# Example of a wrongly classified text: La police a déclaré qu'elle avait trouvé le voleur de la Joconde.
# Example of a wrongly classified text: Puis, plus grand, je découvrais les métiers de policier et d'avocat dans un film
# Example of a wrongly classified text: Bien, l'enquête est terminée, madame.
# Example of a wrongly classified text: Grâce à une enseigante, il a finalement commencé à s'intéresser à l'école.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: L'inégalité entre pays riches et pauvres, ainsi qu'elle saute aux yeux au mitant du dernier siècle, au moment des décolonisations, n'était ni éternelle, ni inévitable.
# Example of a wrongly classified text: C'est injuste On ne peut pas le condamner pour la faute qu'il a commise
# Example of a wrongly classified text: Pour chaque histoire, j'écoute l'audio et en même j'écris ce que je comprends.
# Example of a wrongly classified text: Et j'adresse un défi collectif au parterre !
# Text correctly classified
# Example of a wrongly classified text: Cette deuxième explication plus tardive semble avoir l'avantage pour certains de retirer les Amérindiens de l'équation, ce qui entache d'autant sa crédibilité
# Text correctly classified
# Example of a wrongly classified text: Plusieurs jours se passèrent de la sorte.
# Example of a wrongly classified text: Tous les collèges ne sont pas équipés de casiers .
# Text correctly classified
# Example of a wrongly classified text: C'est la saison la plus chaude, pendant laquelle on recommence à mettre ses lunettes de soleil et à aller se promener sur la plage
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Enfin, les producteurs s'inquiètent de la pollution que peuvent entraîner ces équipements qui contiennent parfois des substances dangereuses.
# Text correctly classified
# Example of a wrongly classified text: Or, Internet et les réseaux sociaux mobilisent toute notre attention et ne permettent pas de trouver cette tranquillité d'esprit.
# Text correctly classified
# Example of a wrongly classified text: Ne renonce jamais aux cruautés qui vivifient la passion et lui redonnent du lustre.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Le réalisateur m'a d'abord demandé de me mettre devant la caméra.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Plusieurs pays ont commencé à appliquer les principes d'une gestion intelligente d'une ressource longtemps considérée comme inépuisable.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Non, moi plus tard, je ferai des marionnettes comme mon papa.
# Text correctly classified
# Example of a wrongly classified text: Après, je vais dans la cuisine et je bois mon café
# Text correctly classified
# Example of a wrongly classified text: Mais, ce soir-là, Quentin était sorti
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Je n'ai pas de leçons à recevoir.
# Example of a wrongly classified text: Le Falcon 1 est un lanceur théoriquement réutilisable qui peut placer, selon son constructeur, 670 kg en orbite basse.
# Example of a wrongly classified text: Saul Goodman est un avocat véreux et peut être facilement trouvé dans les pages jaunes d'Albuquerque.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Le montant des recettes des impôts sur l'énergie dépend non seulement du taux d'imposition, mais aussi de la quantité d'énergie consommée, elle-même influencée par la situation économique, les conditions météorologiques et les prix.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Enseigner à une enfant qu'il peut réussir.
# Text correctly classified
# Example of a wrongly classified text: Il explora tout le rez-de-chaussée et découvrit un appentis, ou plutôt un petit hangar encombré de vieilles caisses et de deux carcasses de camionnettes.
# Example of a wrongly classified text: En Occasionnel, il s'agit de 15 manches maximum, la première équipe à gagner 8 manches l'emporte.
# Text correctly classified
# Example of a wrongly classified text: À partir de deux reportages sur les vacances des Français, invitez les apprenants à parler de leurs vacances.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Je te conseille vraiment la Brasserie du Métro qui est mon restaurant préféré, tu ne le regretteras pas si tu y vas
# Text correctly classified
# Example of a wrongly classified text: Par ailleurs, des éducateurs expliquent que ce n'est pas en poursuivant ces enfants que l'on réglera les problèmes des familles.
# Text correctly classified
# Example of a wrongly classified text: En Compétitif, il s'agit de 30 manches, l'équipe gagnant 16 manches l'emporte, mais le match se termine par une égalité si aucune des deux équipes n'a atteint 16 à la fin de la trentième manche.
# Example of a wrongly classified text: Au rez-de-chaussée, il y a un salon avec un piano, une salle-à-manger, une cuisine spacieuse et jaune et une salle de bain
# Example of a wrongly classified text: Il l'a suivie, emporté par les flots.
# Example of a wrongly classified text: Il est primordial que le gouvernement poursuive ses efforts pour conforter la reprise économique dans ce pays
# Example of a wrongly classified text: Plus d'un s'imposait un quart volontaire dans les barres de perroquet, qui eût maudit une telle corvée en toute autre circonstance.
# Example of a wrongly classified text: Il y a des régions où les enfants ne vont pas à l'école le mercredi.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Nous lisions ensemble des poètes anglais ; nous nous promenions ensemble.
# Text correctly classified
# Example of a wrongly classified text: Salut tout le monde
# Text correctly classified
# Example of a wrongly classified text: Malgré cela, des protestataires continuent à descendre dans les rues pour demander le départ des généraux putschistes et la libération des centaines de détenus emprisonnés ces dernières semaines.
# Example of a wrongly classified text: Après l'éruption de 1754, la plus grosse connue par le volcan qui avait tué plus d'un millier de personnes, la municipalité de San Nicolas avait à l'époque déménagé sept kilomètres plus loin pour s'éloigner du volcan
# Example of a wrongly classified text: Elle préfère aussi mettre un pull, des chaussettes en laine, des bottes et ses gants pour ne pas avoir froid aux doigts
# Text correctly classified
# Example of a wrongly classified text: Morin : "Notre mode de connaissance parcellisée prédit des ignorances globales.
# Text correctly classified
# Example of a wrongly classified text: Originaire des Saintes, un archipel situé au sud de la Guadeloupe, Gérard-Michel a un parcours pour le moins atypique
# Example of a wrongly classified text: On n'en sort pas, et moi, j'en ai marre.
# Example of a wrongly classified text: Mais il faut continuer.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Je dirais qu'Andy Warhol est l'artiste le plus complexe, multi-facettes et révolutionnaire de ces soixante dernières années.
# Example of a wrongly classified text: J'ai fait de gros progrès en français, je le comprends et je sais le parler et l'écrire bien mieux maintenant
# Text correctly classified
# Example of a wrongly classified text: Le temps des hommes s'articule autour de ce jour chômé.
# Example of a wrongly classified text: On pourra se faire un cinéma ou un bowling à l'occasion si tu veux ?
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: "Aujourd'hui nous magnifions les robots pour faciliter leur future acceptation sociale", relève le psychiatre Serge Tisseron de l'université Paris-VII, dans le magazine Les dossiers de la Recherche. Mais cette forte empathie peut avoir son revers.
# Example of a wrongly classified text: Trois hommes et une femme ont été abattus lors d'un rassemblement anti-coup d'Etat dans la ville de Monywa (centre), ont indiqué à l'AFP des sources médicales.
# Example of a wrongly classified text: Accusé de vol, l'homme a fini par avouer qu'il était coupable.
# Example of a wrongly classified text: Une petite révolution et des chiffres qui parlent tout seuls.
# Example of a wrongly classified text: À part ça, je fais du sport trois ou quatre fois par semaine.
# Text correctly classified
# Example of a wrongly classified text: On peut aussi aller au théâtre, dans les musées ou au cinéma
# Example of a wrongly classified text: " à ses proches
# Example of a wrongly classified text: Puis je me bagarrais avec Daffy, mon canard en peluche, je mâchouillais mon os qui couine ou je chantais à l'unisson avec la radio de la voisine
# Example of a wrongly classified text: La dynamique de la vie de ces couples, ponctuée par des crises successives et des étapes semblables à celles de n'importe quel couple, a pourtant sa logique propre.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Avant de boire une tasse de café, il faut faire pousser le plan de café, le récolter, le transporter, l'emballer, le vendre et le préparer
# Example of a wrongly classified text: Cet homme a une belle allure.
# Text correctly classified
# Example of a wrongly classified text: Entre-temps, après avoir réalisé un bénéfice, Piero acheta une plaque décorée d'un coeur transpercé d'une flèche qu'il donna au paysan.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Ce que la porte était bien incapable de faire!
# Text correctly classified
# Example of a wrongly classified text: Cependant dans certains cas, les exploitants veulent rentabiliser leur concession au maximum et dans des délais beaucoup trop courts d'un point de vue écologique.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Au milieu de ces collines aux formes admirables et se précipitant vers le lac par des pentes si singulières, je puis garder toutes les illusions des descriptions du Tasse et de l'Arioste.
# Text correctly classified
# Example of a wrongly classified text: Ce sont des jours fériés, c'est-à-dire des jours pendant lesquels on ne travaille pas
# Example of a wrongly classified text: Un héritier : un héritier est une personne qui reçoit des droits ou un patrimoine après la mort d'une personne.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Il ne reste pas seul chez lui ce soir
# Example of a wrongly classified text: Étant féru d'art, Yves Saint Laurent a constitué, au fil des années, une importante collection d'objets précieux et de peintures qui ont inspiré certaines de ses créations.
# Text correctly classified
# Example of a wrongly classified text: Cerveau et seau de plage jouent-ils les vases communicants ?
# Example of a wrongly classified text: Pour remédier à une suspicion d'endogénéité, plusieurs variables instrumentales potentielles sont proposées.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Voilà le chemin à suivre, finissons-en avec ce décalage inacceptable entre la cuisine d'en haut (consommée par une minorité) et la cuisine d'en bas, celle de la majorité silencieuse, débordante et insipide.
# Example of a wrongly classified text: Le massacre est commémoré sur le drapeau de la ville de Chicago par sa première étoile rouge
# Text correctly classified
# Example of a wrongly classified text: Ma chère Sonia, Je suis bien arrivée à Londres pour ma dernière année d'études de marketing à l'université.
# Example of a wrongly classified text: Un rêve d'enfant réalisé.
# Example of a wrongly classified text: Enfin j'entendis sonner l'heure à laquelle je devais me rendre chez le comte.
# Text correctly classified
# Example of a wrongly classified text: On peut y aller à pied
# Example of a wrongly classified text: Pour le plat de résistance de ce soir, je n'ai ni de tomates, ni de courgettes dans mon garde-manger.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Il y a un an, j'ai décidé de ne plus manger de viande.
# Text correctly classified
# Example of a wrongly classified text: Or, aujourd'hui, c'est un défi massif lancé à notre pays.
# Example of a wrongly classified text: Quand Arthur rentrait enfin, je lui faisais la fête en sautant dans tous les sens, et il me sortions pour notre promenade au parc, caressait derrière les oreilles en ria Ensuite, nous où nous retrouvions quelques amis
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Quand elle vécut cette catastrophe hors norme, soudain elle perdit son sang froid.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: L'enseignement des langues dans l'école française est - comment dire ça poliment
# Example of a wrongly classified text: Il y a aussi une table basse.
# Example of a wrongly classified text: Chaque printemps, la Quinzaine du commerce équitable est l'occasion de lancer de grandes campagnes de sensibilisation.
# Example of a wrongly classified text: Pour pallier le manque de compétences transversales, la créativité dans les salles de classe de tous âges pourrait être le fait des élèves eux-mêmes, en devenant des "proconsommateurs" - producteurs et consommateurs - de connaissances.
# Example of a wrongly classified text: "Parce que les révisions aident à faire retrouver la trace du rangement au sein de sa mémoire, ajoute-t-il
# Text correctly classified
# Example of a wrongly classified text: Cette année, ce n'est pas moins de 12 millions d'élèves qui ont repris le chemin de l'école.
# Example of a wrongly classified text: Bref : réfléchir à l'utilisation que vous allez en avoir et non pas en fonction du prix, même mini !
# Example of a wrongly classified text: Sur les 40 hommes et femmes présents, 32 étaient séparés ou en instance de divorce.
# Example of a wrongly classified text: L'extrémité supérieure de la corde est attachée à une planchette doublée de liège, et une branche de coudrier très flexible, fichée sur cette planchette, soutient une petite sonnette qui tinte lorsque le poisson, pris à la ligne, donne des secousses à la corde.
# Text correctly classified
# Example of a wrongly classified text: Au fils des pages, je doutais qu'ils eussent écrit ces lignes et proses de ses propres mains.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: La deuxième phase correspond à une période de bilinguisme émergent.
# Text correctly classified
# Example of a wrongly classified text: Pourquoi le gouvernement a-t-il décidé une extension du public visé ?
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Sans parler des cantines d'entreprises, des bistrots branchés, des snacks et des bars de quartier.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Chère Anna, Je ne suis pas encore prêt pour comprendre toute l'histoire, Mais tes vidéos sont extrêmement motivantes!
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: La locomotive, dirigée par le bras d'un mécanicien anglais et chauffée de houille anglaise, lançait sa fumée sur les plantations de cotonniers, de caféiers, de muscadiers, de girofliers, de poivriers rouges.
# Example of a wrongly classified text: L'image d'un robot esclave n'est pas neuve! Les progrès présents et promis inquiètent certaines personnes qui redoutent d'être supplantées par des machines.
# Example of a wrongly classified text: Elle s'appelle Folio et elle a un an.
# Text correctly classified
# Example of a wrongly classified text: Le journaliste lui a posé des questions auxquelles il a répondu sans hésitations.
# Example of a wrongly classified text: Il me reste des croissants.
# Example of a wrongly classified text: Je suis restée quatre semaines à Boston dans une famille.
# Text correctly classified
# Example of a wrongly classified text: Il n'y a pas beaucoup de voitures donc il n'y a pas d'embouteillage
# Text correctly classified
# Example of a wrongly classified text: Plus tôt, ils avaient été remis à un procureur, escortés de 15 officiers de police japonais venus spécialement aux États-Unis samedi pour l'occasion.
# Text correctly classified
# Example of a wrongly classified text: Ce phénomène, c'est l'apparition d'une génération inédite.
# Example of a wrongly classified text: Une large majorité de français est favorable à la modification du calcul de la retraite des fonctionnaires dans le cadre de la réforme en préparation, selon un sondage publié vendredi
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Ils sont allés en vacances l'été dernier
# Example of a wrongly classified text: Je m'agitais ainsi intérieurement, lorsque je fis connaissance avec le comte de P ***, homme de quarante ans, dont la famille était alliée à la mienne.
# Example of a wrongly classified text: Fini les pâtes à l'italienne, les gros haricots blancs, les pommes de terre en robe des champs avec du beurre et du bon pain frais.
# Example of a wrongly classified text: J'espère qu'il y aura beaucoup de soleil.
# Text correctly classified
# Example of a wrongly classified text: Personne ne doit être reçu dans les fortifications par faveur ou par recommandation.
# Text correctly classified
# Example of a wrongly classified text: Le train de ma soeur arrive à 20h05
# Example of a wrongly classified text: Vous avez une réduction ?
# Example of a wrongly classified text: La longueur est une distance mais une sensation aussi.
# Example of a wrongly classified text: À l'occasion de la manifestation, qui se déroule dans tout le pays, les organisateurs ont commandé un sondage.
# Text correctly classified
# Example of a wrongly classified text: Qu'ils soient mariés depuis des années ou vivant pour la première fois sous le même toit, le confinement va mettre tous les couples à l'épreuve.
# Text correctly classified
# Example of a wrongly classified text: Ma contrainte avec lui eut une grande influence sur mon caractère.
# Example of a wrongly classified text: D'autres instruments ont "sniffé" les gaz à la surface de la comète et la récolte a été bonne. Le robot, qui pèse 100 kg sur la Terre, a une masse d'un gramme sur la comète, a recueilli une mine d'images et de données scientifiques, transmis à la sonde Rosetta qui les a renvoyés sur Terre.
# Text correctly classified
# Example of a wrongly classified text: Certains métiers vont disparaître, mais d'autres apparaître.
# Text correctly classified
# Example of a wrongly classified text: Comment est votre blanquette ?
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Bref, première leçon, le québécois n'est pas un français déformé mais plutôt un français historique, proche de celui qui était parlé en France avant le 17e siècle
# Example of a wrongly classified text: Innovation et simplicité sont les jalons du seul chemin à parcourir pour retrouver concrètement et durablement un élan créatif adapté à un monde qui change, évolue mais reste friand de bonnes choses.
# Example of a wrongly classified text: A l'origine, Bergmann et Sams, qui ont véritablement fait découvrir la méthode, ont travaillé avec des capsules vidéo, donc ce qui suppose un enregistrement.
# Example of a wrongly classified text: La religion est la grande consolatrice des virginités
# Text correctly classified
# Example of a wrongly classified text: La blanquette est bonne.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Le petit chat plaît à mes parents.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: J'ai bien reçu ton message
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Je crois que c'est surtout pour me faire plaisir.
# Text correctly classified
# Example of a wrongly classified text: Devant chaque porte se trouvait une botte de paille, pour empêcher le froid de passer dessous.
# Example of a wrongly classified text: Rencontrant dans mon cours de biologie une notion complexe, je descendis pour aller demander à mon père d'éclairer ma lanterne.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: L'absence d'ivrognerie rend praticables les plus basses classes de Constantinople, et les Orientaux ont une dignité naturelle inconnue chez nous.
# Example of a wrongly classified text: Aujourd'hui, c'est une tarte aux framboises avec de la confiture faite maison
# Example of a wrongly classified text: Quand j'étais petit, ma mère, elle m'entendait chanter et elle me disait "Jamais tu seras dans la musique, toi !"
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Soyons sérieux
# Example of a wrongly classified text: D'ici là, "l'infosphère" continuera son expansion vertigineuse ; la masse de connaissances double déjà tous les deux ans.
# Text correctly classified
# Example of a wrongly classified text: S'il existe des dizaines de variantes à cette recette, le chef Gérard- Michel Corbin nous propose d'y apporter lui aussi sa touche personnelle
# ...
# Example of a wrongly classified text: Elle présente un style très cohérent, car elle a été construite assez rapidement.
# Example of a wrongly classified text: Il y a beaucoup de désordre dans l'appartement.
# Example of a wrongly classified text: J'ai une arme, et toi non.
# Example of a wrongly classified text: Ainsi, une grande partie des espèces végétales ou animales en péril ne sont connues à l'heure actuelle que par certains peuples, dont les langues s'éteignent.
# Text correctly classified
# Example of a wrongly classified text: Cette femme mourut seule et misérable.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Ils l'appelaient tous monseigneur, et ils riaient quand il faisait des contes.
# Text correctly classified
# Example of a wrongly classified text: D'abord, les produits fabriqués en France sont en moyenne 30 pour cent plus chers que les autres
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Il suffit de rester 30 minutes dans la cabine LIRVA pour être capable de se débrouiller dans toutes les situations de la vie quotidienne et dans la langue de son choix.
# Example of a wrongly classified text: Le repos absolu produit le spleen.
# Example of a wrongly classified text: J'espère que tu vas bien et que tes vacances au ski se passent bien aussi
# Text correctly classified
# Example of a wrongly classified text: À 40 ans, il est usé.
# Example of a wrongly classified text: Elles étaient très amies mais l'une des deux est partie en Suède.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Ce triomphe, dont le marquis jouissait avec une insolence rare, ne dura que quelques mois, et fut suivi d'un revers humiliant.
# Example of a wrongly classified text: Vous avez des enfants ?
# Example of a wrongly classified text: Ce mémoire concerne l'étude de la retrocycloaddition d'oxazolidines conduisant a l'espece reactive ylure d'azomethine.
# Example of a wrongly classified text: Il a trouvé un copain.
# Text correctly classified
# Example of a wrongly classified text: Il faut prendre la mesure de ces bouleversements pour repenser les contenus scolaires, les manières de les enseigner et de les apprendre.
# Text correctly classified
# Example of a wrongly classified text: Le soir, je regarde la télé jusqu'à 11 heures.
# Text correctly classified
# Example of a wrongly classified text: À l'ère de l'Internet des Objets, les maisons intelligentes sont de plus en plus équipés d'objets connectés, dont les implications sur la vie privée restent largement inconnues des utilisateurs finaux.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Il peut survenir à toute heure, mais de préférence quand un petit rayon de soleil réchauffe votre ordinateur.
# Example of a wrongly classified text: Et toi, qu'est-ce que tu as prévu pendant les vacances ?
# Text correctly classified
# Example of a wrongly classified text: Environ 2 300 enseignants et chercheurs ainsi que 950 collaborateurs administratifs et techniques assurent la bonne marche de l'institution qui compte plus de 14 000 étudiants provenant de plus de 86 pays.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Lorsqu'un cinéaste adapte un livre au cinéma, il donne sa propre vision de ce livre.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Ce processus d'homogénéisation s'est renforcé avec l'industrialisation et le progrès scientifique, qui ont imposé de nouveaux modes de communication, rapides, simples et pratiques.
# Example of a wrongly classified text: C'était une pièce vide et triste ; aux parois lépreuses des murs s'effiloquaient des débris d'affiches officielles
# Text correctly classified
# Example of a wrongly classified text: Pour l'économiste Jeremy Rifkin, dont le livre La Fin du Travail suscita un large débat, le travail est sur la pente d'un inexorable déclin.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Où est-ce que tu travaillais avant d'être avec nous ici ?
# Example of a wrongly classified text: Ces enfants s'étaient procuré quelques petites clefs, et quand la nuit était bien noire, ils essayaient d'ouvrir les cadenas de ces chaînes qui attachent les bateaux à quelque grosse pierre ou à quelque arbre voisin du rivage.
# Example of a wrongly classified text: Un journaliste de Art Press a interviewé Agathe sur la performance dans laquelle elle a participé.
# Example of a wrongly classified text: L'artiste peignit un paysage qu'il eut vu
# Text correctly classified
# Example of a wrongly classified text: Walter White est professeur de chimie dans un lycée, et vit avec son fils handicapé moteur et sa femme enceinte à Albuquerque, au Nouveau-Mexique.
# Text correctly classified
# Example of a wrongly classified text: Je saute et vous n'aurez jamais les plans !
# Text correctly classified
# Example of a wrongly classified text: Dans le centre de la ville, il y a un très joli quartier, plein de magasins chics et de bons restaurants. Pour se déplacer, il y a des bus, des vélos et un métro.
# Example of a wrongly classified text: J'adore ça.
# Example of a wrongly classified text: Au sein du gouvernement français, rares sont ceux qui peuvent afficher sur leur CV ne serait-ce qu'une année à la fac!
# Example of a wrongly classified text: La marche était cassée et je suis tombé par terre.
# Example of a wrongly classified text: Quelle est la plus belle qualité de la femme d'Azaël ?
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Il sut comment poursuivre dans les prés les poulains à demi sauvages, comment les approcher en secret, les surprendre d'un saut et les maintenir par force, les par la fatigue.
# Example of a wrongly classified text: Son accent est si naturel que cela n'a posé aucun problème.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: S'obstiner à acheter 100 pour cent français reviendrait à vivre sans réfrigérateur, sans lave linge, sans smartphone, sans ordinateur. Autrement dit, les plus patriotes et les plus écolos devront soit mettre de l'eau dans leur vin soit revenir à un mode de vie d'un autre âge
# Example of a wrongly classified text: Cette quête de l'altérité zonale laissa au milieu du XXe une marque géographique frappante : lorsque s'imposa l'idée de tiers-monde, il s'avéra que les pays sous-développés étaient alors très majoritairement situés dans la zone intertropicale, le "Sud".
# Example of a wrongly classified text: L'originalité du mécanisme est d'utiliser des photons et de les convertir en énergie chimique qui se retrouve dans l'énergie de liaison des atomes de carbone et d'hydrogène dans les glucides formés.
# Example of a wrongly classified text: Selon les familles, la soirée peut être animée par des lectures de contes horrifiques ou de poème évoquant Halloween.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Edgar, étincelant de furie, dominait tous les autres de sa voix plus claire.
# Text correctly classified
# Example of a wrongly classified text: Pour l'heure, l'isolement à l'improviste semble leur réussir : ils ont ouvert une bouteille de champagne pour fêter leur emménagement ensemble et en gardent une au frais pour célébrer la fin du confinement.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: C'est un fait inquiétant qu'on constate dans toutes les capitales européennes : les touristes séjournent de plus en plus dans des appartements loués sur des sites internet.
# Example of a wrongly classified text: Je vous demanderai de tout lui montrer et de le seconder cette semaine.
# Example of a wrongly classified text: Le domestique de Fabrice s'approcha avec les deux chevaux.
# Example of a wrongly classified text: Un enseignement scolaire pour créer des liens entre les matières
# Text correctly classified
# Example of a wrongly classified text: Cette ribaude ricane et échafaude !
# Example of a wrongly classified text: Je ne comprends rien à ce site d'achat en ligne !
# Text correctly classified
# Example of a wrongly classified text: Les responsables européens sont dos au mur.
# Example of a wrongly classified text: Mais la chute de Neera Tanden annonce les autres batailles plus rudes à venir au Sénat
# Example of a wrongly classified text: Genre de plantes de la pentandrie trigynie et de la famille des portulacées, dont les caractères consistent : en un calice infundibuliforme, à limbe divisé en cinq parties.
# Text correctly classified
# Example of a wrongly classified text: Parce que la philosophie se trouve de plus en plus mobilisée en étendard face à un religieux invasif ou agressif, et parce qu'elle prend aujourd'hui les traits d'une quasi-religion laïque, un ouvrage comme celui de Pierre Bouretz brouille des pistes trop tracées.
# Example of a wrongly classified text: Le brun, aussi appelé marron, est la couleur du café, de la terre et de l'écorce des arbres.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Dans le cadre d'une recherche en sociolinguistique urbaine, s'intéressant aux parlers de jeunes en parcours d'insertion sociale et professionnelle, évoluant au sein de centres de formation, nous nous sommes interrogées sur la construction et l'hétérogénéité des interactions dans le cadre de situations de communication données, dont témoigne la diversité des corpus recueillis.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Je prends congé aujourd'hui : je suis fatigué et j'ai besoin de repos.
# Text correctly classified
# Example of a wrongly classified text: Réponds-moi vite et fais ta réservation pour venir.
# Example of a wrongly classified text: Par contre, les sports d'équipe comme le foot ou le basket, je n'aime pas du tout !
# Example of a wrongly classified text: Pendant que les humains bavardaient, Mimi le caniche, Fido le berger allemand et moi, on se donnait les nouvelles du quartier et on reniflait les nouveaux arrivants
# Example of a wrongly classified text: Personne n'a envie de vivre dans la rue.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Elle a dû faire beaucoup de rééducation mais elle est presque rétablie maintenant.
# Example of a wrongly classified text: Nous avons reçu plusieurs plaintes à ce sujet.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Tout le contraire de moi.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: C'est pourquoi, il décida de remplacer les habituelles portes automatiques par des portiers en superbe livrée, ce qui donna un caractère très luxueux à cet aéroport.
# Example of a wrongly classified text: Elle raconte leur quotidien à travers les enfants qu'elle a aussi aidés à faire leurs devoirs
# Example of a wrongly classified text: La force des livres de Marie NDiaye réside dans la frontière indéterminée entre le réalisme et l'onirisme.
# Text correctly classified
# Example of a wrongly classified text: L'univers des francophones est un métissage unique et fertile
# Text correctly classified
# Example of a wrongly classified text: La compétence fiscale des communes est réduite car elle dépend du droit cantonal.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: C'est un gentil bouledogue qui aime les câlins.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Quand l'homme de condition moyenne devient un grand personnage, les flatteries commencent à se terner et les médisances à fleurir
# Text correctly classified
# Example of a wrongly classified text: Il faut aussi poser des questions sur le travail et les horaires de l'entreprise
# Text correctly classified
# Example of a wrongly classified text: Elle se retrouvait dans les lectures de sa jeunesse, en plein Walter Scott.
# Example of a wrongly classified text: Grâce à un bienfaiteur, Julien a grandi dans une famille qui s'est occupée de lui et qui l'a éduqué.
# Example of a wrongly classified text: Ma mère est allemande et est avocate
# Example of a wrongly classified text: Les Cyanobactéries se distinguent des Bactéries par la présence de chlorophylle A et de pigments accessoires hydrosolubles, les phycobilines rouge et bleue.
# Text correctly classified
# Example of a wrongly classified text: Je m'appelle Laurent et j'habite à Paris avec mes parents, ma soeur ainée et mon frère.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Quelques sermons de quelques hypocondriaques sont-ils à ce point, parvenus à déconcilier l'Algérien avec sa santé ?
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Mets ça sur ton pied, ça va soulager la douleur.
# Example of a wrongly classified text: Quand vous voyez toutes ces blessures, tous ces dégâts occasionnés par un cyclone, c'est monumental
# Example of a wrongly classified text: Quoique habillé d'un complet de soixante francs, il gardait une certaine élégance tapageuse, un peu commune, réelle cependant.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Ma mère viendra en France.
# Example of a wrongly classified text: T'as pas honte.
# Example of a wrongly classified text: Il joue de la guitare dans un bar.
# Example of a wrongly classified text: Elle cherche un travail de réceptionniste dans un hôtel
# Example of a wrongly classified text: Il faisait toujours très beau et surtout très chaud
# Text correctly classified
# Example of a wrongly classified text: Je ne t'ai pas téléphoné parce que j'ai eu trop de travail.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: J'ai écris un roman, c'est le premier, je ne sais pas si c'est le premier, je ne sais pas si j'en écrirai d'autres.
# Example of a wrongly classified text: Les mois de mars et avril passent en accéléré : procès, rendez-vous médicaux, concerts, ballets, devoirs et match de baseball s'enchaînent à une vitesse incroyable, et pendant tout ce temps, le ventre de Chelsea ne cesse de s'étirer.
# Example of a wrongly classified text: Chéri, tu pourrais me masser le haut du dos, s'il te plaît ?
# Example of a wrongly classified text: Si vous voulez attendre au bar, on vous appellera quand ce sera prêt.
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Le soir, ils sont allés à un concert
# Example of a wrongly classified text: Mais il y a un problème .
# Example of a wrongly classified text: Si j'appuie là, c'est douleureux.
# Example of a wrongly classified text: Le slogan "100 % de nos clients achètent nos produits" est une tautologie.
# Text correctly classified
# Text correctly classified
# Text correctly classified
# Example of a wrongly classified text: Et il y a en ce sens comme une chute temporelle de Jésus s'abaissant pour s'accommoder aux concepts hébraïques.
# Example of a wrongly classified text: En été, j'aime faire de la randonnée et vous, que faites-vous le soir en hiver ?
# Example of a wrongly classified text: J'écris un peu.
# Text correctly classified
# Example of a wrongly classified text: Tous les prix sont affichés, mais si besoin, j'ai mis la liste des prix à côté de la caisse.
# Example of a wrongly classified text: Très présente dans l'alimentation antillaise, la morue a été introduite aux Petites Antilles par les premiers colons
# Example of a wrongly classified text: On réinvente le dimanche dans une perspective laïque.
# Example of a wrongly classified text: Pour les femmes surtout, nuancent Régine Lemoine-Darthois et Elisabeth Weissman.

# %% [markdown]
# Now we can generate predictions on the `unlabelled_test_data.csv`, insuring that they match the format of the `unlabelled_test_data.csv` in order to submit them.

# %%
x_pred = df_pred['sentence']

y_prediction_lr = pipe.predict(x_pred)
y_prediction_lr
# Out:
# array(['C2', 'B1', 'A1', ..., 'C2', 'A2', 'B1'], dtype=object)

# %%
df_pred_lr = df_pred
df_pred_lr['difficulty'] = y_prediction_lr
df_submission_lr = df_pred_lr.drop(['sentence'], axis=1)
df_submission_lr.to_csv('subimissionlr.csv',index=False)
df_submission_lr.head()
# Out:
#    id difficulty
# 0   0         C2
# 1   1         B1
# 2   2         A1
# 3   3         B1
# 4   4         C2
